# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
import os
import importlib
script_dir = os.getcwd()  
sys.path.append(os.path.abspath(os.path.join(script_dir, '..')))
import src.data
importlib.reload(src.data) 

import pandas as pd
from src.paths import TRANSFORMED_DATA_DIR

features_and_target = pd.read_parquet(TRANSFORMED_DATA_DIR / "tabular_data.parquet")  # load-in the training-data parquet file
features_and_target
# Out:
#        rides_previous_672_hour  rides_previous_671_hour  \
# 0                         11.0                     15.0
# 1                          1.0                      0.0
# 2                          0.0                      1.0
# 3                          1.0                      1.0
# 4                          0.0                      0.0
# ...                        ...                      ...
# 88289                      0.0                      0.0
# 88290                      0.0                      0.0
# 88291                      0.0                      0.0
# 88292                      0.0                      0.0
# 88293                      0.0                      0.0
#
#        rides_previous_670_hour  rides_previous_669_hour  \
# 0                         26.0                      8.0
# 1                          2.0                      0.0
# 2                          0.0                      0.0
# 3                          0.0                      0.0
# ...

# %%
# split the train-data into features/targets
features = features_and_target.drop(columns=["target_rides_next_hour"])   # train-data-df drop the target-column to get only the features
targets = features_and_target["target_rides_next_hour"]                   # only select teh target column to get only the targets
print(f"features: {features.shape=}")
print(f"targets: {targets.shape=}")
features["rides_previous_672_hour"][0]
# Out:
# features: features.shape=(88294, 674)
# targets: targets.shape=(88294,)
# 11.0

# %%
# WARNING: the ploting of training-tabular-data is not working
from src.plot import plot_one_sample, hello

plot_one_sample(features, targets, 0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 from src.plot import plot_one_sample, hello
# ----> 3 plot_one_sample(features, targets, 0)
#
# File ~/Documents/Real World ML Tutorial/Taxi Demand Predictor Project/taxi_demand_predictor/src/plot.py:15, in plot_one_sample(example_id, features, targets, predictions, display_title)
#       7 def plot_one_sample(
#       8     example_id: int,
#       9     features: pd.DataFrame,
#    (...)
#      12     display_title: Optional[bool] = True,
#      13 ):
#      14     """"""
# ---> 15     features_ = features.iloc[example_id]
#      17     if targets is not None:
#      18         target_ = targets.iloc[example_id]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
# ...
